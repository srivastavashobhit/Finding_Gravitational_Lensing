# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = Image.open('../data/kdsb/train/images/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.jpg')
img = img.convert('RGB')

img_resized = img.resize((125, 125), Image.ANTIALIAS)
edge = cv2.Canny(np.asarray(np.uint8(img_resized)),10,1000)
type(img_resized)
# Out:
# /tmp/ipykernel_40442/1282906945.py:4: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img_resized = img.resize((125, 125), Image.ANTIALIAS)
# PIL.Image.Image

# %%
plt.imshow(img_resized)

# %%
plt.imshow(img)

# %%
img = np.load('../data/images_shri.npy')

# %%
image = img[0]

# %%
image = image.resize()
# Out:
# (125, 125, 3)
